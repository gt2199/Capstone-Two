# %% [markdown]
# # Modeling - ARIMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")
from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

# %% [markdown]
# ## Load training data

# %%
data = pd.read_csv('../data/interim/energy_weather_features_train.csv',index_col=0)

# %%
data.index = pd.DatetimeIndex(data.index).to_period('H')

# %%
data = data.sort_index()

# %%
data.head()
# Out:
#                    energy  humidity  pressure  temperature          weather  \
# datetime
# 2012-10-01 13:00  11426.0      71.0    1014.0   284.010000  overcast clouds
# 2012-10-01 14:00  11522.0      70.0    1014.0   284.054691  overcast clouds
# 2012-10-01 15:00  11574.0      70.0    1014.0   284.177412  overcast clouds
# 2012-10-01 16:00  11489.0      70.0    1014.0   284.300133  overcast clouds
# 2012-10-01 17:00  11309.0      69.0    1014.0   284.422855  overcast clouds
#
#                   wind_direction  wind_speed  weather_broken clouds  \
# datetime
# 2012-10-01 13:00             0.0         0.0                      0
# 2012-10-01 14:00             0.0         0.0                      0
# 2012-10-01 15:00             0.0         0.0                      0
# 2012-10-01 16:00             0.0         0.0                      0
# 2012-10-01 17:00             0.0         0.0                      0
#
#                   weather_drizzle  weather_few clouds  ...  \
# ...

# %%
data.index
# Out:
# PeriodIndex(['2012-10-01 13:00', '2012-10-01 14:00', '2012-10-01 15:00',
#              '2012-10-01 16:00', '2012-10-01 17:00', '2012-10-01 18:00',
#              '2012-10-01 19:00', '2012-10-01 20:00', '2012-10-01 21:00',
#              '2012-10-01 22:00',
#              ...
#              '2016-12-31 14:00', '2016-12-31 15:00', '2016-12-31 16:00',
#              '2016-12-31 17:00', '2016-12-31 18:00', '2016-12-31 19:00',
#              '2016-12-31 20:00', '2016-12-31 21:00', '2016-12-31 22:00',
#              '2016-12-31 23:00'],
#             dtype='period[H]', name='datetime', length=35884, freq='H')

# %%
plt.figure(figsize=(15,4))
data['energy'].plot()
plt.show()

# %% [markdown]
# ## Load testing data

# %%
data_test = pd.read_csv('../data/interim/energy_weather_features_test.csv',index_col=0)
data_test.index = pd.DatetimeIndex(data_test.index).to_period('H')
data_test = data_test.sort_index()

# %%
plt.figure(figsize=(15,4))
data_test['energy'].plot()
plt.show()

# %%
data_test.head()
# Out:
#                    energy  humidity  pressure  temperature           weather  \
# datetime
# 2017-01-01 00:00  10500.0     100.0    1011.0       274.06   overcast clouds
# 2017-01-01 01:00  10197.0      50.0    1011.0       272.94  scattered clouds
# 2017-01-01 02:00   9893.0     100.0    1012.0       272.14      sky is clear
# 2017-01-01 03:00   9654.0      63.0    1012.0       270.97      sky is clear
# 2017-01-01 04:00   9437.0      73.0    1014.0       270.14      sky is clear
#
#                   wind_direction  wind_speed  weather_broken clouds  \
# datetime
# 2017-01-01 00:00           300.0         4.0                      0
# 2017-01-01 01:00           290.0         4.0                      0
# 2017-01-01 02:00           270.0         3.0                      0
# 2017-01-01 03:00           250.0         3.0                      0
# 2017-01-01 04:00           220.0         1.0                      0
#
#                   weather_drizzle  weather_few clouds  ...  \
# ...

# %%
from statsmodels.tsa.stattools import adfuller
results = adfuller(data['energy'])
print('The p-value of the test on returns is: ' + str(results[1]))
# Out:
# The p-value of the test on returns is: 6.064998008569807e-25

# %% [markdown]
# Since the p-value is extremely small, we can reject the null hypothesis that the data is a random walk.

# %% [markdown]
# # ARIMA Model

# %%
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

# %% [markdown]
# ## Tune hyperparameters

# %% [markdown]
# Due to the large number of data points, we'll use only the year 2013 for tuning hyperparameters (p,q,d). The model is selected based on the Akaike's Information Criteria (AIC).

# %%
train_data = data.loc['2013'][['energy']]

ps = [0,1,2,3,4,5]
qs = [0,1,2,3,4,5]
ds = [0,1,2,3,4,5]
minaic = 10000000000
for p in ps:
    for q in qs:
        for d in ds:
            try:
                model = ARIMA(train_data, order=(p,q,d))
                result = model.fit()
                if result.aic < minaic:
                    minaic = result.aic
                    minbic = result.bic
                    optp = p
                    optq = q
                    optd = d
            except:
                continue
print(optp,optq,optd,minaic,minbic)
# Out:
# 4 1 5 114800.36309588332 114877.35755052207

# %% [markdown]
# From the optimization above, the optimal p, q, and d are 4, 1, and 5. This means that the model only requres 4 lags in the historical data (4 hours), 1 degree of differencing to account for non-stationary (1 hour), and size 5 moving average window (5 hours).

# %% [markdown]
# ## Plot predictions

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Here, we check the model forcasts versus the real data.

# %%
train_data = data_test.loc['2017'][['energy']]
plt.rc("figure", figsize=(15,4))
model = ARIMA(train_data, order=(4,1,5))
result = model.fit()
result.plot_predict(start='2017', end='2017')
plt.show()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:               D.energy   No. Observations:                 7990
# Model:                 ARIMA(4, 1, 5)   Log Likelihood              -53211.779
# Method:                       css-mle   S.D. of innovations            188.769
# Date:                Tue, 04 Jan 2022   AIC                         106445.557
# Time:                        08:58:08   BIC                         106522.403
# Sample:                    01-01-2017   HQIC                        106471.862
#                          - 11-30-2017
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0631      2.519      0.025      0.980      -4.875       5.001
# ar.L1.D.energy     1.3631      0.015     89.029      0.000       1.333       1.393
# ...

# %%
result.save('../models/arima.pkl')

# %%
my_predict = result.predict(start='2017', end='2017',typ='levels')

# %%
rmse = np.sqrt(mean_squared_error(train_data[1:], my_predict))
print(rmse)
# Out:
# 188.8071054463053

# %% [markdown]
# # ARIMA Model + features

# %% [markdown]
# Here, we can add additional features (exogeneous variables) to our optimized ARIMA model. Since the temperature appears to be correlated with energy based on EDA, only normalized temperature data are added.

# %% [markdown]
# ## Plot predictions

# %%
train_data = data_test.loc['2017'][['energy']]
features_predict = data_test.loc['2017'][['n_temperature']]

plt.rc("figure", figsize=(15,4))
model_x1 = ARIMA(train_data, exog=features_predict, order=(4,1,5))
result_x1 = model_x1.fit()
result_x1.plot_predict(start='2017', end='2017')
plt.title('ARIMA + temperature')
plt.tight_layout()
plt.savefig('forecast_arima.png')
plt.show()

# %%
result_x1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:               D.energy   No. Observations:                 7990
# Model:                 ARIMA(4, 1, 5)   Log Likelihood              -53023.784
# Method:                       css-mle   S.D. of innovations            184.386
# Date:                Tue, 04 Jan 2022   AIC                         106071.567
# Time:                        08:59:08   BIC                         106155.399
# Sample:                    01-01-2017   HQIC                        106100.263
#                          - 11-30-2017
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.7066      3.416     -0.207      0.836      -7.402       5.989
# n_temperature      3.1279      3.783      0.827      0.408      -4.286      10.542
# ...

# %%
result_x1.save('../models/arima_x.pkl')

# %%
my_predict = result_x1.predict(start='2017', end='2017',typ='levels')

# %%
rmse = np.sqrt(mean_squared_error(train_data[1:], my_predict))
print(rmse)
# Out:
# 184.42543831701187

# %% [markdown]
# Comparing the ARIMA two models, the original model without additional features has higher AIC than the model with exogeneous feature (106445.557 versus 106071.567). The performance is also reflected on their RMSE were the original model is an RMSE of 188.8, where the additional temperature feature reduces the RMSE to 184.4.
#
# Thus, including the weather data such as temperatures in this case can improve the performance.
